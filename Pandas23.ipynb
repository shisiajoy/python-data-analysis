# %% [markdown]
# <a href="https://colab.research.google.com/github/Shisiajoy/PYTHON-DATA-ANALYSIS/blob/main/Pandas23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Iris
#
# Introduction:
#
# This exercise may seem a little bit strange, but keep doing it.
#
# Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Step 2. Import the dataset from this address.
#
# Step 3. Assign it to a variable called iris

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
iris = pd.read_csv(url)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   5.1          149 non-null    float64
#  1   3.5          149 non-null    float64
#  2   1.4          149 non-null    float64
#  3   0.2          149 non-null    float64
#  4   Iris-setosa  149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
iris.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
iris.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %% [markdown]
# Step 4. Create columns for the dataset

# %%
# 1. sepal_length (in cm)
# 2. sepal_width (in cm)
# 3. petal_length (in cm)
# 4. petal_width (in cm)
# 5. class

# %%
iris.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %% [markdown]
# Step 5. Is there any missing value in the dataframe?

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %% [markdown]
# Step 6. Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
iris.loc[10:29, 'petal_length'] = np.nan

# %%
iris.head(35)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 0            4.9          3.0           1.4          0.2  Iris-setosa
# 1            4.7          3.2           1.3          0.2  Iris-setosa
# 2            4.6          3.1           1.5          0.2  Iris-setosa
# 3            5.0          3.6           1.4          0.2  Iris-setosa
# 4            5.4          3.9           1.7          0.4  Iris-setosa
# 5            4.6          3.4           1.4          0.3  Iris-setosa
# 6            5.0          3.4           1.5          0.2  Iris-setosa
# 7            4.4          2.9           1.4          0.2  Iris-setosa
# 8            4.9          3.1           1.5          0.1  Iris-setosa
# 9            5.4          3.7           1.5          0.2  Iris-setosa
# 10           4.8          3.4           NaN          0.2  Iris-setosa
# 11           4.8          3.0           NaN          0.1  Iris-setosa
# ...

# %% [markdown]
# Step 7. Good, now lets substitute the NaN values to 1.0

# %%
iris['petal_length'].fillna(1.0, inplace=True)

# %%
iris.head(35)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 0            4.9          3.0           1.4          0.2  Iris-setosa
# 1            4.7          3.2           1.3          0.2  Iris-setosa
# 2            4.6          3.1           1.5          0.2  Iris-setosa
# 3            5.0          3.6           1.4          0.2  Iris-setosa
# 4            5.4          3.9           1.7          0.4  Iris-setosa
# 5            4.6          3.4           1.4          0.3  Iris-setosa
# 6            5.0          3.4           1.5          0.2  Iris-setosa
# 7            4.4          2.9           1.4          0.2  Iris-setosa
# 8            4.9          3.1           1.5          0.1  Iris-setosa
# 9            5.4          3.7           1.5          0.2  Iris-setosa
# 10           4.8          3.4           1.0          0.2  Iris-setosa
# 11           4.8          3.0           1.0          0.1  Iris-setosa
# ...

# %% [markdown]
# Step 8. Now let's delete the column class

# %%
iris.drop('class', axis=1, inplace=True)

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')

# %% [markdown]
# Step 9. Set the first 3 rows as NaN

# %%
iris.loc[:2, :] = np.nan

# %%
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1           NaN          NaN           NaN          NaN
# 2           NaN          NaN           NaN          NaN
# 3           5.0          3.6           1.4          0.2
# 4           5.4          3.9           1.7          0.4

# %% [markdown]
# Step 10. Delete the rows that have NaN

# %%
iris.dropna(inplace=True)

# %%
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 3           5.0          3.6           1.4          0.2
# 4           5.4          3.9           1.7          0.4
# 5           4.6          3.4           1.4          0.3
# 6           5.0          3.4           1.5          0.2
# 7           4.4          2.9           1.4          0.2

# %% [markdown]
# Step 11. Reset the index so it begins with 0 again

# %%
iris.reset_index(drop=True, inplace=True)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.0          3.6           1.4          0.2
# 1           5.4          3.9           1.7          0.4
# 2           4.6          3.4           1.4          0.3
# 3           5.0          3.4           1.5          0.2
# 4           4.4          2.9           1.4          0.2

# %% [markdown]
# BONUS: Create your own question and answer it.
#
#  Step 12. Perform sumary statistics

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    146.000000   146.000000    146.000000   146.000000
# mean       5.871233     3.050000      3.756164     1.226027
# std        0.821098     0.437745      1.838214     0.755125
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.125000     2.800000      1.500000     0.325000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
