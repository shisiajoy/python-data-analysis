# %% [markdown]
# <a href="https://colab.research.google.com/github/Shisiajoy/PYTHON-DATA-ANALYSIS/blob/main/pandas17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# US - Baby Names
#
# Introduction:
#
# We are going to use a subset of US Baby Names from Kaggle.
# In the file it will be names from 2004 until 2014
#
# Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# US - Baby Names
#
# Introduction:
#
# We are going to use a subset of US Baby Names from Kaggle.
# In the file it will be names from 2004 until 2014
#
# Step 1. Import the necessary libraries

# %%
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv"
baby_names = pd.read_csv(url)

# %% [markdown]
# Step 4. See the first 10 entries

# %%
baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %% [markdown]
# Step 5. Delete the column 'Unnamed: 0' and 'Id'

# %%
baby_names.reset_index()
# Out:
#            index  Unnamed: 0       Id     Name  Year Gender State  Count
# 0              0       11349    11350     Emma  2004      F    AK     62
# 1              1       11350    11351  Madison  2004      F    AK     48
# 2              2       11351    11352   Hannah  2004      F    AK     46
# 3              3       11352    11353    Grace  2004      F    AK     44
# 4              4       11353    11354    Emily  2004      F    AK     41
# ...          ...         ...      ...      ...   ...    ...   ...    ...
# 1016390  1016390     5647421  5647422     Seth  2014      M    WY      5
# 1016391  1016391     5647422  5647423  Spencer  2014      M    WY      5
# 1016392  1016392     5647423  5647424     Tyce  2014      M    WY      5
# 1016393  1016393     5647424  5647425   Victor  2014      M    WY      5
# 1016394  1016394     5647425  5647426   Waylon  2014      M    WY      5
#
# [1016395 rows x 8 columns]

# %%
baby_names.drop(columns=['Unnamed: 0' , 'Id'], inplace=True, errors='ignore')

# %%
baby_names.head()
# Out:
#       Name  Year Gender State  Count
# 0     Emma  2004      F    AK     62
# 1  Madison  2004      F    AK     48
# 2   Hannah  2004      F    AK     46
# 3    Grace  2004      F    AK     44
# 4    Emily  2004      F    AK     41

# %% [markdown]
# Step 6. Is there more male or female names in the dataset?

# %%
gender_counts = baby_names['Gender'].value_counts()
print("More male names" if gender_counts['M'] > gender_counts['F'] else "More female names")
# Out:
# More female names

# %% [markdown]
# Step 7. Group the dataset by name and assign to names

# %%
names = baby_names.groupby('Name').sum()

# %%
names.head(10)
# Out:
#            Year                                             Gender  \
# Name
# Aaban      4027                                                 MM
# Aadan      8039                                               MMMM
# Aadarsh    2009                                                  M
# Aaden    393963  MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...
# Aadhav     2014                                                  M
# Aadhya    80515           FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# Aadi      76340             MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM
# Aadin      2008                                                  M
# Aadit      6029                                                MMM
# Aaditya   28116                                     MMMMMMMMMMMMMM
#
#                                                      State  Count
# Name
# Aaban                                                 NYNY     12
# Aadan                                             CACACATX     23
# ...

# %% [markdown]
# Step 8. How many different names exist in the dataset?

# %%
len(names)
# Out:
# 17632

# %% [markdown]
# Step 9. What is the name with most occurrences?

# %%
names['Count'].idxmax()
# Out:
# 'Jacob'

# %% [markdown]
# Step 10. How many different names have the least occurrences?

# %%
names[names['Count'] == names['Count'].min().sum()]
# Out:
#           Year Gender State  Count
# Name
# Aadarsh   2009      M    IL      5
# Aadin     2008      M    TX      5
# Aaima     2013      F    NY      5
# Aalaya    2014      F    CA      5
# Aaminah   2004      F    CA      5
# ...        ...    ...   ...    ...
# Zyien     2009      M    TX      5
# Zyire     2007      M    NY      5
# Zykeriah  2008      F    AL      5
# Zykierra  2007      F    GA      5
# Zymari    2009      M    NC      5
#
# [2578 rows x 4 columns]

# %% [markdown]
# Step 11. What is the median name occurrence?

# %%
names['Count'].median()
# Out:
# 49.0

# %% [markdown]
# Step 12. What is the standard deviation of names?

# %%
names['Count'].std()
# Out:
# 11006.06946789057

# %% [markdown]
# Step 13. Get a summary with the mean, min, max, std and quartiles.

# %%
print("Summary of name occurrences:")
names['Count'].describe()
# Out:
# Summary of name occurrences:
# count     17632.000000
# mean       2008.932169
# std       11006.069468
# min           5.000000
# 25%          11.000000
# 50%          49.000000
# 75%         337.000000
# max      242874.000000
# Name: Count, dtype: float64
