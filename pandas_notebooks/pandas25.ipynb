# %% [markdown]
# <a href="https://colab.research.google.com/github/Shisiajoy/PYTHON-DATA-ANALYSIS/blob/main/pandas25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Getting Financial Data
#  - Google Finance
#
# Introduction:
#
# This time you will get data from a website.
#
# Step 1. Import the necessary libraries

# %%
pip install yfinance

# %%
import yfinance as yf
import pandas as pd

# %% [markdown]
# Step 2. Create your time range (start and end variables). The start date should be 01/01/2015 and the end should today (whatever your today is)

# %%
start_date = '2015-01-01'
end_date = '2024-04-14'

# %% [markdown]
# Step 3. Select the Apple, Tesla, Twitter, IBM, LinkedIn stocks symbols and assign them to a variable called stocks

# %%
stock = 'AAPL' , 'TSLA' , 'IBM' , 'LNKD' , 'TWR'

# %% [markdown]
# Step 4. Read the data from google, assign to df and print it

# %%
df=yf.download(stock ,start_date,end_date)
# Out:
# [*********************100%%**********************]  5 of 5 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['LNKD']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2015-01-01 -> 2024-04-14)')

# %%
df.head()
# Out:
# Price       Adj Close                                        Close  \
# Ticker           AAPL         IBM LNKD       TSLA   TWR       AAPL
# Date
# 2015-01-02  24.435270  103.354843  NaN  14.620667  0.03  27.332500
# 2015-01-05  23.746891  101.728554  NaN  14.006000  0.04  26.562500
# 2015-01-06  23.749125   99.534660  NaN  14.085333  0.04  26.565001
# 2015-01-07  24.082136   98.884178  NaN  14.063333  0.04  26.937500
# 2015-01-08  25.007427  101.033394  NaN  14.041333  0.03  27.972500
#
# Price                                         ...       Open                   \
# Ticker             IBM LNKD       TSLA   TWR  ...       AAPL         IBM LNKD
# Date                                          ...
# 2015-01-02  154.933075  NaN  14.620667  0.03  ...  27.847500  154.216064  NaN
# 2015-01-05  152.495224  NaN  14.006000  0.04  ...  27.072500  154.177826  NaN
# 2015-01-06  149.206497  NaN  14.085333  0.04  ...  26.635000  152.648178  NaN
# ...

# %%
df.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',  'IBM'),
#             ('Adj Close', 'LNKD'),
#             ('Adj Close', 'TSLA'),
#             ('Adj Close',  'TWR'),
#             (    'Close', 'AAPL'),
#             (    'Close',  'IBM'),
#             (    'Close', 'LNKD'),
#             (    'Close', 'TSLA'),
#             (    'Close',  'TWR'),
#             (     'High', 'AAPL'),
#             (     'High',  'IBM'),
#             (     'High', 'LNKD'),
#             (     'High', 'TSLA'),
#             (     'High',  'TWR'),
#             (      'Low', 'AAPL'),
#             (      'Low',  'IBM'),
#             (      'Low', 'LNKD'),
#             (      'Low', 'TSLA'),
#             (      'Low',  'TWR'),
#             (     'Open', 'AAPL'),
#             (     'Open',  'IBM'),
#             (     'Open', 'LNKD'),
#             (     'Open', 'TSLA'),
#             (     'Open',  'TWR'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',  'IBM'),
# ...

# %% [markdown]
# Step 5. What is the type of structure of df ?

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# Step 6. Print all the Items axis values
#
# To learn more about the Panel structure go to documentation

# %%
print(df.items)
# Out:
# <bound method DataFrame.items of Price        Adj Close                                          Close  \
# Ticker            AAPL         IBM LNKD        TSLA   TWR        AAPL
# Date
# 2015-01-02   24.435270  103.354843  NaN   14.620667  0.03   27.332500
# 2015-01-05   23.746891  101.728554  NaN   14.006000  0.04   26.562500
# 2015-01-06   23.749125   99.534660  NaN   14.085333  0.04   26.565001
# 2015-01-07   24.082136   98.884178  NaN   14.063333  0.04   26.937500
# 2015-01-08   25.007427  101.033394  NaN   14.041333  0.03   27.972500
# ...                ...         ...  ...         ...   ...         ...
# 2024-04-08  168.449997  189.820007  NaN  172.979996   NaN  168.449997
# 2024-04-09  169.669998  189.309998  NaN  176.880005   NaN  169.669998
# 2024-04-10  167.779999  186.039993  NaN  171.759995   NaN  167.779999
# 2024-04-11  175.039993  185.899994  NaN  174.600006   NaN  175.039993
# 2024-04-12  176.550003  182.270004  NaN  171.050003   NaN  176.550003
#
# ...

# %% [markdown]
# Step 7. Good, now we know the data avaiable. Create a dataFrame called vol, with the Volume values.

# %%
vol = df['Volume']

# %%
vol
# Out:
# Ticker           AAPL      IBM  LNKD       TSLA      TWR
# Date
# 2015-01-02  212818400  5779673   NaN   71466000      0.0
# 2015-01-05  257142000  5104898   NaN   80527500  76000.0
# 2015-01-06  263188400  6429448   NaN   93928500      0.0
# 2015-01-07  160423600  4918083   NaN   44526000      0.0
# 2015-01-08  237458000  4431693   NaN   51637500   2500.0
# ...               ...      ...   ...        ...      ...
# 2024-04-08   37425500  2678300   NaN  104423300      NaN
# 2024-04-09   42451200  2794200   NaN  103232700      NaN
# 2024-04-10   49709300  3081700   NaN   84532400      NaN
# 2024-04-11   91070300  2861700   NaN   94516000      NaN
# 2024-04-12  101593300  3545100   NaN   64506600      NaN
#
# [2335 rows x 5 columns]

# %% [markdown]
# Step 8. Aggregate the data of Volume to weekly
#
# Hint: Be careful to not sum data from the same week of 2015 and other years.

# %%
vol_weekly = vol.resample('W').sum()

# %%
vol_weekly
# Out:
# Ticker            AAPL       IBM  LNKD       TSLA      TWR
# Date
# 2015-01-04   212818400   5779673   0.0   71466000      0.0
# 2015-01-11  1133010000  25578884   0.0  340644000  78500.0
# 2015-01-18  1216906400  24329751   0.0  461988000  78000.0
# 2015-01-25   794948000  32682062   0.0  243175500  76000.0
# 2015-02-01  1863370800  34442689   0.0  235803000  47750.0
# ...                ...       ...   ...        ...      ...
# 2024-03-17   367031800  27536000   0.0  502605300      0.0
# 2024-03-24   361530400  23967800   0.0  417965200      0.0
# 2024-03-31   237622700  15383300   0.0  346873600      0.0
# 2024-04-07   239021300  12881500   0.0  545575500      0.0
# 2024-04-14   322249600  14961000   0.0  451211000      0.0
#
# [485 rows x 5 columns]

# %% [markdown]
# BONUS: Create your own question and answer it
#
# creat a data frame called Adj close with adj close values and aggregate the data to yearly

# %%
adj_close = df['Adj Close']

# %%
adj_close
# Out:
# Ticker            AAPL         IBM  LNKD        TSLA   TWR
# Date
# 2015-01-02   24.435270  103.354843   NaN   14.620667  0.03
# 2015-01-05   23.746891  101.728554   NaN   14.006000  0.04
# 2015-01-06   23.749125   99.534660   NaN   14.085333  0.04
# 2015-01-07   24.082136   98.884178   NaN   14.063333  0.04
# 2015-01-08   25.007427  101.033394   NaN   14.041333  0.03
# ...                ...         ...   ...         ...   ...
# 2024-04-08  168.449997  189.820007   NaN  172.979996   NaN
# 2024-04-09  169.669998  189.309998   NaN  176.880005   NaN
# 2024-04-10  167.779999  186.039993   NaN  171.759995   NaN
# 2024-04-11  175.039993  185.899994   NaN  174.600006   NaN
# 2024-04-12  176.550003  182.270004   NaN  171.050003   NaN
#
# [2335 rows x 5 columns]

# %%
adj_close_yearly = adj_close.resample('Y').sum()

# %%
adj_close_yearly
# Out:
# Ticker              AAPL           IBM  LNKD          TSLA         TWR
# Date
# 2015-12-31   6820.044289  25360.861481   0.0   3864.720658  444.970004
# 2016-12-31   6066.271872  25512.996490   0.0   3524.090007  387.764995
# 2017-12-31   8860.239002  27559.878357   0.0   5259.559326  172.410000
# 2018-12-31  11295.722527  26187.299934   0.0   5309.652658    2.755000
# 2019-12-31  12689.781933  26267.170540   0.0   4595.307343    0.000000
# 2020-12-31  23598.661499  25107.376305   0.0  24456.419268  483.000000
# 2021-12-31  34989.342781  28566.190369   0.0  65519.536758    0.000000
# 2022-12-31  38485.364365  30955.515984   0.0  66036.363327    0.000000
# 2023-12-31  42975.439743  33726.863342   0.0  54368.809891    0.000000
# 2024-12-31  12789.599197  12967.599670   0.0  13631.370041    0.000000
